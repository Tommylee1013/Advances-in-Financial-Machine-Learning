# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt
import seaborn as sns
import FinancialMachineLearning as fml

# %% [markdown]
# ### Chapter 8. Feature Importances
# #### Exercise 1
# 8.6절의 코드를 사용하여 다음을 수행하라
#
# **(a)** Data Set$(X,y)$을 생성하라

# %%
trnsX, const = fml.getTestData(n_features = 40, n_informative = 10, n_redundant = 10, n_samples = 10000)

# %%
trnsX
# Out:
#                  I_0       I_1       I_2       I_3       I_4       I_5  \
# 1985-01-17  2.843740  0.456554  0.171107 -4.511382  0.278990 -3.474726
# 1985-01-18  3.561541 -1.566097  3.342813 -1.938909  2.075749 -3.486711
# 1985-01-21  7.699248 -3.030124 -0.859302 -0.033351  1.113719 -0.877844
# 1985-01-22 -0.149801 -3.182187  2.695894  1.359997  2.992416 -0.417971
# 1985-01-23 -2.157903  0.046380  0.697217 -1.012036  1.856002 -2.311465
# ...              ...       ...       ...       ...       ...       ...
# 2023-05-11  2.489902 -0.523701  0.618210 -1.837222  1.905865  0.051481
# 2023-05-12 -0.742495  1.595855  2.173729  1.420993 -1.619853  1.952217
# 2023-05-15 -0.420406 -0.650531  3.524902 -0.608855 -0.823038  0.070312
# 2023-05-16 -0.697229 -1.974764  0.438944 -0.208492 -0.279182 -1.887733
# 2023-05-17 -3.142547 -4.576872 -1.192787  4.092471 -0.913382 -0.214720
#
#                  I_6       I_7       I_8       I_9  ...      N_10      N_11  \
# 1985-01-17  2.955550  2.698865  1.542440  2.198168  ... -0.330515 -0.845502
# 1985-01-18  0.494908  0.309615  1.059439 -0.792433  ... -0.020384 -0.751467
# 1985-01-21  2.344033  4.089113  2.287786  0.611413  ...  0.744056  0.914181
# 1985-01-22 -1.214058  1.268313 -3.720913 -2.580578  ... -1.960632 -2.064914
# 1985-01-23  2.715493  0.444433 -1.921790 -2.472372  ... -0.841121  0.081347
# ...              ...       ...       ...       ...  ...       ...       ...
# 2023-05-11 -2.072887  1.133835  0.055833 -1.655887  ... -0.013532 -0.215027
# 2023-05-12 -2.131979 -2.340327 -1.629928  0.080561  ...  0.962720 -0.191763
# 2023-05-15 -1.619873 -1.560697 -0.939518 -1.471037  ... -0.176512  0.676007
# 2023-05-16 -1.931841 -1.163289 -0.111943 -0.732073  ...  1.179474 -0.825594
# 2023-05-17 -2.212020 -1.341850 -0.225639 -1.141243  ...  0.772330  2.041646
#
#                 N_12      N_13      N_14      N_15      N_16      N_17  \
# 1985-01-17 -1.477466  1.217536  0.304644  1.557365  0.202843  0.160110
# 1985-01-18  0.212077  0.285038  0.125461  0.203534 -0.376495 -0.938780
# 1985-01-21  1.586483  0.692802 -0.953431  0.679360  0.565153  0.219302
# 1985-01-22  1.258648 -1.031856  0.645146 -0.063900  0.305844  0.371489
# 1985-01-23 -2.587682 -0.416436 -1.077859 -0.428086 -0.183735 -0.434254
# ...              ...       ...       ...       ...       ...       ...
# 2023-05-11  0.869924 -0.932547  0.644979  0.175920  1.353286 -1.436413
# 2023-05-12  2.788231  0.055138  0.807920  0.457464  1.129258  0.273195
# 2023-05-15  0.878948  1.322274 -0.794662  0.646342  0.464202 -1.220561
# 2023-05-16 -0.419181  1.142775 -0.696596 -0.018242  0.090638  1.535604
# 2023-05-17  0.052423  1.953935 -1.333130 -1.097405  0.693821  1.509674
#
#                 N_18      N_19
# 1985-01-17  0.933805 -0.132272
# 1985-01-18 -0.142879  0.533263
# 1985-01-21 -1.110504 -1.086061
# 1985-01-22  3.218969  0.867178
# 1985-01-23 -2.124955 -0.709056
# ...              ...       ...
# 2023-05-11 -0.741075  1.054140
# 2023-05-12  1.419955 -1.095283
# 2023-05-15  0.101444  0.455718
# 2023-05-16 -0.857168  0.433795
# 2023-05-17  1.064864  1.006815
#
# [10000 rows x 40 columns]

# %%
const
# Out:
#             bin       w         t1
# 1985-01-17    0  0.0001 1985-01-17
# 1985-01-18    0  0.0001 1985-01-18
# 1985-01-21    0  0.0001 1985-01-21
# 1985-01-22    0  0.0001 1985-01-22
# 1985-01-23    0  0.0001 1985-01-23
# ...         ...     ...        ...
# 2023-05-11    1  0.0001 2023-05-11
# 2023-05-12    1  0.0001 2023-05-12
# 2023-05-15    1  0.0001 2023-05-15
# 2023-05-16    1  0.0001 2023-05-16
# 2023-05-17    1  0.0001 2023-05-17
#
# [10000 rows x 3 columns]

# %%
imp, oob, oos = fml.featImportance(trnsX, const)
# Out:
# Process SpawnPoolWorker-26:
# Process SpawnPoolWorker-25:
# Process SpawnPoolWorker-27:
# Process SpawnPoolWorker-23:
# Process SpawnPoolWorker-17:
# Process SpawnPoolWorker-24:
# Process SpawnPoolWorker-29:
# Process SpawnPoolWorker-20:
# Traceback (most recent call last):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 32, in <module>
#     from numba import jit
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/numba/__init__.py", line 19, in <module>
#     from numba.core import config
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/numba/core/config.py", line 15, in <module>
#     import llvmlite.binding as ll
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/llvmlite/binding/__init__.py", line 4, in <module>
#     from .dylib import *
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/llvmlite/binding/dylib.py", line 3, in <module>
#     from llvmlite.binding import ffi
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/llvmlite/binding/ffi.py", line 175, in <module>
#     from pkg_resources import resource_filename
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/pkg_resources/__init__.py", line 82, in <module>
#     from pkg_resources.extern.jaraco.text import (
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/pkg_resources/_vendor/jaraco/text/__init__.py", line 11, in <module>
#     from pkg_resources.extern.jaraco.functools import compose, method_cache
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/pkg_resources/_vendor/jaraco/functools.py", line 8, in <module>
#     import pkg_resources.extern.more_itertools
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 666, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 565, in module_from_spec
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/pkg_resources/extern/__init__.py", line 52, in create_module
#     return self.load_module(spec.name)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/pkg_resources/extern/__init__.py", line 37, in load_module
#     __import__(extant)
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 941, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1040, in get_data
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 32, in <module>
#     from numba import jit
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/numba/__init__.py", line 19, in <module>
#     from numba.core import config
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/numba/core/config.py", line 15, in <module>
#     import llvmlite.binding as ll
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/llvmlite/binding/__init__.py", line 4, in <module>
#     from .dylib import *
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/llvmlite/binding/dylib.py", line 3, in <module>
#     from llvmlite.binding import ffi
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/llvmlite/binding/ffi.py", line 175, in <module>
#     from pkg_resources import resource_filename
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/pkg_resources/__init__.py", line 82, in <module>
#     from pkg_resources.extern.jaraco.text import (
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/pkg_resources/_vendor/jaraco/text/__init__.py", line 11, in <module>
#     from pkg_resources.extern.jaraco.functools import compose, method_cache
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/pkg_resources/_vendor/jaraco/functools.py", line 8, in <module>
#     import pkg_resources.extern.more_itertools
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 666, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 565, in module_from_spec
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/pkg_resources/extern/__init__.py", line 52, in create_module
#     return self.load_module(spec.name)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/pkg_resources/extern/__init__.py", line 37, in load_module
#     __import__(extant)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/pkg_resources/_vendor/more_itertools/__init__.py", line 3, in <module>
#     from .more import *  # noqa
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 982, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 925, in _find_spec
# Process SpawnPoolWorker-21:
# KeyboardInterrupt
# Process SpawnPoolWorker-22:
# Process SpawnPoolWorker-15:
# Process SpawnPoolWorker-19:
# Process SpawnPoolWorker-18:
# Traceback (most recent call last):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 8, in <module>
#     import seaborn as sns
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/seaborn/__init__.py", line 2, in <module>
#     from .rcmod import *  # noqa: F401,F403
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/seaborn/rcmod.py", line 7, in <module>
#     from . import palettes
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/seaborn/palettes.py", line 9, in <module>
#     from .utils import desaturate, get_color_cycle
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py", line 10, in <module>
#     from scipy import stats
#   File "<frozen importlib._bootstrap>", line 1055, in _handle_fromlist
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py", line 200, in __getattr__
#     return _importlib.import_module(f'scipy.{name}')
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/__init__.py", line 485, in <module>
# Exception ignored in: <module 'threading' from '/Users/tommylee/opt/anaconda3/lib/python3.9/threading.py'>
# Traceback (most recent call last):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/threading.py", line 1428, in _shutdown
#     from ._stats_py import *
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_stats_py.py", line 46, in <module>
# Exception ignored in: <module 'threading' from '/Users/tommylee/opt/anaconda3/lib/python3.9/threading.py'>
# Traceback (most recent call last):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/threading.py", line 1428, in _shutdown
#     from . import distributions
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/distributions.py", line 8, in <module>
#     from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_distn_infrastructure.py", line 25, in <module>
#     from scipy import integrate
#   File "<frozen importlib._bootstrap>", line 1055, in _handle_fromlist
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py", line 200, in __getattr__
#     return _importlib.import_module(f'scipy.{name}')
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/scipy/integrate/__init__.py", line 101, in <module>
#     from . import dop, lsoda, vode, odepack, quadpack
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 950, in get_code
#   File "<frozen importlib._bootstrap_external>", line 585, in _classify_pyc
#   File "<frozen importlib._bootstrap_external>", line 81, in _unpack_uint32
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
# Process SpawnPoolWorker-16:
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 129, in _main
#     return self._bootstrap(parent_sentinel)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 331, in _bootstrap
#     def _shutdown():
# KeyboardInterrupt:
#     def _shutdown():
# KeyboardInterrupt:
# Traceback (most recent call last):
#     traceback.print_exc()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 163, in print_exc
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 103, in print_exception
#     for line in TracebackException(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 517, in __init__
#     self.run()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self.stack = StackSummary.extract(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 366, in extract
#     f.line
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 288, in line
#     self._line = linecache.getline(self.filename, self.lineno).strip()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/linecache.py", line 30, in getline
#     self._target(*self._args, **self._kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     res = self._reader.recv_bytes()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/connection.py", line 221, in recv_bytes
#     lines = getlines(filename, module_globals)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/linecache.py", line 46, in getlines
#     buf = self._recv_bytes(maxlength)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     return updatecache(filename, module_globals)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/tokenize.py", line 394, in open
#     buf = self._recv(4)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
# Traceback (most recent call last):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     encoding, lines = detect_encoding(buffer.readline)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/tokenize.py", line 363, in detect_encoding
#     exitcode = _main(fd, parent_sentinel)
# Traceback (most recent call last):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     first = read_or_stop()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/tokenize.py", line 321, in read_or_stop
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 129, in _main
#     return self._bootstrap(parent_sentinel)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 331, in _bootstrap
#     return readline()
# KeyboardInterrupt
#     traceback.print_exc()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 163, in print_exc
#     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 103, in print_exception
#     for line in TracebackException(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 517, in __init__
#     self.stack = StackSummary.extract(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 366, in extract
#     f.line
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 288, in line
#     self._line = linecache.getline(self.filename, self.lineno).strip()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/tokenize.py", line 394, in open
#     encoding, lines = detect_encoding(buffer.readline)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/tokenize.py", line 313, in detect_encoding
#     filename = readline.__self__.name
# KeyboardInterrupt
# Process SpawnPoolWorker-31:
# Traceback (most recent call last):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
# Process SpawnPoolWorker-30:
#     self.run()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
# Traceback (most recent call last):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 2014, in expandCall
#     self.run()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     out = func(**kargs)  # put the arguments into the function
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1488, in auxFeatImpSFI
#     result = (True, func(*args, **kwds))
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 2014, in expandCall
#     df0 = cvScore(clf, X=trnsX[[featName]], y=cont['bin'], sample_weight=cont['w'], scoring=scoring, cvGen=cvGen)
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1310, in cvScore
#     out = func(**kargs)  # put the arguments into the function
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1488, in auxFeatImpSFI
#     fit = clf.fit(X = pd.DataFrame(X).iloc[train, :], y = pd.DataFrame(y).iloc[train],
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 269, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 394, in _fit
#     all_results = Parallel(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 1043, in __call__
#     df0 = cvScore(clf, X=trnsX[[featName]], y=cont['bin'], sample_weight=cont['w'], scoring=scoring, cvGen=cvGen)
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1310, in cvScore
#     fit = clf.fit(X = pd.DataFrame(X).iloc[train, :], y = pd.DataFrame(y).iloc[train],
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 269, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 394, in _fit
#     all_results = Parallel(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 1043, in __call__
#     self._target(*self._args, **self._kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 2014, in expandCall
#     out = func(**kargs)  # put the arguments into the function
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1488, in auxFeatImpSFI
#     df0 = cvScore(clf, X=trnsX[[featName]], y=cont['bin'], sample_weight=cont['w'], scoring=scoring, cvGen=cvGen)
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1310, in cvScore
#     fit = clf.fit(X = pd.DataFrame(X).iloc[train, :], y = pd.DataFrame(y).iloc[train],
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 269, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 394, in _fit
#     all_results = Parallel(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 1043, in __call__
# Traceback (most recent call last):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
# Process SpawnPoolWorker-32:
# Traceback (most recent call last):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
# Traceback (most recent call last):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
# Traceback (most recent call last):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.
# KeyboardInterrupt
# py", line 2014, in expandCall
#     self.run()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 2014, in expandCall
#     out = func(**kargs)  # put the arguments into the function
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1488, in auxFeatImpSFI
#     df0 = cvScore(clf, X=trnsX[[featName]], y=cont['bin'], sample_weight=cont['w'], scoring=scoring, cvGen=cvGen)
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1310, in cvScore
#     fit = clf.fit(X = pd.DataFrame(X).iloc[train, :], y = pd.DataFrame(y).iloc[train],
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 269, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 394, in _fit
#     all_results = Parallel(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 861, in dispatch_one_batch
#     if self.dispatch_one_batch(iterator):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 861, in dispatch_one_batch
#     if self.dispatch_one_batch(iterator):
#     if self.dispatch_one_batch(iterator):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 861, in dispatch_one_batch
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 779, in _dispatch
#     self._dispatch(tasks)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 779, in _dispatch
#     self._dispatch(tasks)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     self._dispatch(tasks)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     result = ImmediateResult(func)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     result = ImmediateResult(func)
#     out = func(**kargs)  # put the arguments into the function
#     result = ImmediateResult(func)
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1488, in auxFeatImpSFI
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     df0 = cvScore(clf, X=trnsX[[featName]], y=cont['bin'], sample_weight=cont['w'], scoring=scoring, cvGen=cvGen)
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1310, in cvScore
#     fit = clf.fit(X = pd.DataFrame(X).iloc[train, :], y = pd.DataFrame(y).iloc[train],
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 269, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 394, in _fit
#     all_results = Parallel(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     self.run()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     self.run()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     result = (True, func(*args, **kwds))
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 2014, in expandCall
#     out = func(**kargs)  # put the arguments into the function
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1488, in auxFeatImpSFI
#     df0 = cvScore(clf, X=trnsX[[featName]], y=cont['bin'], sample_weight=cont['w'], scoring=scoring, cvGen=cvGen)
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1310, in cvScore
#     fit = clf.fit(X = pd.DataFrame(X).iloc[train, :], y = pd.DataFrame(y).iloc[train],
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 269, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 394, in _fit
#     all_results = Parallel(
#     self.results = batch()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     self.results = batch()
#     self.results = batch()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#     return [func(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     self.results = batch()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#     return [func(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 216, in __call__
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 216, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 216, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 216, in __call__
#     self._target(*self._args, **self._kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 2014, in expandCall
#     out = func(**kargs)  # put the arguments into the function
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1488, in auxFeatImpSFI
#     df0 = cvScore(clf, X=trnsX[[featName]], y=cont['bin'], sample_weight=cont['w'], scoring=scoring, cvGen=cvGen)
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1310, in cvScore
#     fit = clf.fit(X = pd.DataFrame(X).iloc[train, :], y = pd.DataFrame(y).iloc[train],
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 269, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 394, in _fit
#     all_results = Parallel(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 779, in _dispatch
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 1043, in __call__
#     result = ImmediateResult(func)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     self.results = batch()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 216, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 216, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 216, in __call__
#     self.run()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 2014, in expandCall
#     out = func(**kargs)  # put the arguments into the function
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1488, in auxFeatImpSFI
#     df0 = cvScore(clf, X=trnsX[[featName]], y=cont['bin'], sample_weight=cont['w'], scoring=scoring, cvGen=cvGen)
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1310, in cvScore
#     fit = clf.fit(X = pd.DataFrame(X).iloc[train, :], y = pd.DataFrame(y).iloc[train],
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 269, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 394, in _fit
#     all_results = Parallel(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 216, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 123, in _parallel_build_estimators
#     estimator.fit(X[:, features], y, sample_weight=curr_sample_weight)
#     return self.function(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 937, in fit
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 123, in _parallel_build_estimators
#     estimator.fit(X[:, features], y, sample_weight=curr_sample_weight)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 937, in fit
#     return self.function(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 123, in _parallel_build_estimators
#     return self.function(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 123, in _parallel_build_estimators
#     estimator.fit(X[:, features], y, sample_weight=curr_sample_weight)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 937, in fit
#     return self.function(*args, **kwargs)
#     return self.function(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 123, in _parallel_build_estimators
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 123, in _parallel_build_estimators
#     estimator.fit(X[:, features], y, sample_weight=curr_sample_weight)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 937, in fit
#     return self.function(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 123, in _parallel_build_estimators
#     estimator.fit(X[:, features], y, sample_weight=curr_sample_weight)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 937, in fit
#     estimator.fit(X[:, features], y, sample_weight=curr_sample_weight)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 937, in fit
#     estimator.fit(X[:, features], y, sample_weight=curr_sample_weight)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 937, in fit
#     return self.function(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 123, in _parallel_build_estimators
#     estimator.fit(X[:, features], y, sample_weight=curr_sample_weight)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 937, in fit
# Traceback (most recent call last):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/mu
# ltiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# KeyboardInterrupt
#     super().fit(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 420, in fit
#     super().fit(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 420, in fit
#     super().fit(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 220, in fit
#     super().fit(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 420, in fit
#     super().fit(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 220, in fit
#     expanded_class_weight = compute_sample_weight(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/class_weight.py", line 167, in compute_sample_weight
#     super().fit(
#     super().fit(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 420, in fit
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 420, in fit
#     super().fit(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 420, in fit
#     builder.build(self.tree_, X, y, sample_weight)
#     builder.build(self.tree_, X, y, sample_weight)
#     builder.build(self.tree_, X, y, sample_weight)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#     expanded_class_weight = compute_sample_weight(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/class_weight.py", line 142, in compute_sample_weight
#     builder.build(self.tree_, X, y, sample_weight)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#     builder.build(self.tree_, X, y, sample_weight)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 129, in _main
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     return self._bootstrap(parent_sentinel)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 331, in _bootstrap
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
#   File "<string>", line 1, in <module>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#     traceback.print_exc()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 163, in print_exc
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     builder.build(self.tree_, X, y, sample_weight)
#     classes_full = np.unique(y_full)
#   File "<__array_function__ internals>", line 5, in unique
#     weight_k = compute_class_weight(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/class_weight.py", line 48, in compute_class_weight
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 129, in _main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 129, in _main
#     y_ind = le.fit_transform(y)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py", line 116, in fit_transform
#     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 103, in print_exception
#     return self._bootstrap(parent_sentinel)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 331, in _bootstrap
#     for line in TracebackException(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 517, in __init__
#     return self._bootstrap(parent_sentinel)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 331, in _bootstrap
#     traceback.print_exc()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 163, in print_exc
#     self.stack = StackSummary.extract(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 366, in extract
#     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 103, in print_exception
#     traceback.print_exc()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 163, in print_exc
#     for line in TracebackException(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 517, in __init__
#     f.line
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 288, in line
#     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 103, in print_exception
#     self._line = linecache.getline(self.filename, self.lineno).strip()
#     self.stack = StackSummary.extract(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 350, in extract
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/linecache.py", line 30, in getline
#     for line in TracebackException(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 517, in __init__
#     lines = getlines(filename, module_globals)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/linecache.py", line 46, in getlines
#     name = co.co_name
# KeyboardInterrupt
#     self.stack = StackSummary.extract(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 366, in extract
#     return updatecache(filename, module_globals)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/linecache.py", line 93, in updatecache
#     f.line
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 288, in line
#     stat = os.stat(fullname)
# KeyboardInterrupt
#     self._line = linecache.getline(self.filename, self.lineno).strip()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/linecache.py", line 137, in updatecache
#     lines = fp.readlines()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/codecs.py", line 319, in decode
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#     exitcode = _main(fd, parent_sentinel)
# ...
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1310, in cvScore
#     result = (True, func(*args, **kwds))
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 2014, in expandCall
#     df0 = cvScore(clf, X=trnsX[[featName]], y=cont['bin'], sample_weight=cont['w'], scoring=scoring, cvGen=cvGen)
#     fit = clf.fit(X = pd.DataFrame(X).iloc[train, :], y = pd.DataFrame(y).iloc[train],
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1310, in cvScore
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 269, in fit
#     out = func(**kargs)  # put the arguments into the function
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1488, in auxFeatImpSFI
#     return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 394, in _fit
#     fit = clf.fit(X = pd.DataFrame(X).iloc[train, :], y = pd.DataFrame(y).iloc[train],
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 269, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 394, in _fit
#     df0 = cvScore(clf, X=trnsX[[featName]], y=cont['bin'], sample_weight=cont['w'], scoring=scoring, cvGen=cvGen)
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1310, in cvScore
#     all_results = Parallel(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 1043, in __call__
#     all_results = Parallel(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 1043, in __call__
#     out = func(**kargs)  # put the arguments into the function
#     fit = clf.fit(X = pd.DataFrame(X).iloc[train, :], y = pd.DataFrame(y).iloc[train],
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1488, in auxFeatImpSFI
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 269, in fit
#     fit = clf.fit(X = pd.DataFrame(X).iloc[train, :], y = pd.DataFrame(y).iloc[train],
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 269, in fit
#     return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#     if self.dispatch_one_batch(iterator):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 394, in _fit
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 861, in dispatch_one_batch
#     if self.dispatch_one_batch(iterator):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 861, in dispatch_one_batch
#     fit = clf.fit(X = pd.DataFrame(X).iloc[train, :], y = pd.DataFrame(y).iloc[train],
#     all_results = Parallel(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 269, in fit
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 1043, in __call__
#     self._dispatch(tasks)
#     self._dispatch(tasks)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 779, in _dispatch
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 779, in _dispatch
#     return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 394, in _fit
#     return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 394, in _fit
#     if self.dispatch_one_batch(iterator):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 861, in dispatch_one_batch
#     all_results = Parallel(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 1043, in __call__
#     job = self._backend.apply_async(batch, callback=cb)
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#     result = ImmediateResult(func)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self._dispatch(tasks)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 779, in _dispatch
#     if self.dispatch_one_batch(iterator):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 861, in dispatch_one_batch
#     self.results = batch()
#     self.results = batch()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     all_results = Parallel(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 1043, in __call__
#     return [func(*args, **kwargs)
#     return [func(*args, **kwargs)
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     self._dispatch(tasks)
#     df0 = cvScore(clf, X=trnsX[[featName]], y=cont['bin'], sample_weight=cont['w'], scoring=scoring, cvGen=cvGen)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 779, in _dispatch
#   File "/Users/tommylee/Desktop/Pycharm/Financial_Machine_Learning/FinancialMachineLearning.py", line 1310, in cvScore
#     return [func(*args, **kwargs)
#     return [func(*args, **kwargs)
#     if self.dispatch_one_batch(iterator):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 216, in __call__
#     fit = clf.fit(X = pd.DataFrame(X).iloc[train, :], y = pd.DataFrame(y).iloc[train],
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 216, in __call__
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 269, in fit
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 861, in dispatch_one_batch
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     return self.function(*args, **kwargs)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
#     return self.function(*args, **kwargs)
#     self._dispatch(tasks)
#     return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
# Traceback (most recent call last):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 779, in _dispatch
#   File "<string>", line 1, in <module>
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_bagging.py", line 394, in _fit
#     result = ImmediateResult(func)
#     result = ImmediateResult(func)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/contextlib.py", line 137, in __exit__
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     all_results = Parallel(
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 1043, in __call__
#     self.gen.throw(typ, value, traceback)
#     job = self._backend.apply_async(batch, callback=cb)
# KeyboardInterrupt
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#     result = ImmediateResult(func)
#     self.results = batch()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 861, in dispatch_one_batch
#     return [func(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     self.results = batch()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     self.results = batch()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 216, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 219, in __exit__
#     self._dispatch(tasks)
#     return [func(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 784, in _dispatch
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 220, in __exit__
#     return self.function(*args, **kwargs)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/contextlib.py", line 137, in __exit__
#     def __exit__(self, type, value, traceback):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#     self.unregister()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#     self.gen.throw(typ, value, traceback)
#   File "<string>", line 1, in <module>
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/_config.py", line 179, in config_context
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     self._jobs.insert(job_idx, job)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#     set_config(**old_config)
#   File "<string>", line 1, in <module>
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/site-packages/sklearn/_config.py", line 88, in set_config
#     local_config = _get_threadlocal_config()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
#     exitcode = _main(fd, parent_sentinel)
# Traceback (most recent call last):
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 129, in _main
#   File "<string>", line 1, in <module>
#     return self._bootstrap(parent_sentinel)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 331, in _bootstrap
#     traceback.print_exc()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 163, in print_exc
#     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 105, in print_exception
#     print(line, file=file, end="")
# KeyboardInterrupt
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 129, in _main
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     return self._bootstrap(parent_sentinel)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 331, in _bootstrap
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 129, in _main
#     return self._bootstrap(parent_sentinel)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 331, in _bootstrap
#     traceback.print_exc()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 163, in print_exc
#     traceback.print_exc()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 163, in print_exc
#     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 105, in print_exception
#     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 105, in print_exception
#     print(line, file=file, end="")
# KeyboardInterrupt
#     print(line, file=file, end="")
# KeyboardInterrupt
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 129, in _main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 129, in _main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/spawn.py", line 129, in _main
#     return self._bootstrap(parent_sentinel)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 331, in _bootstrap
#     return self._bootstrap(parent_sentinel)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 331, in _bootstrap
#     return self._bootstrap(parent_sentinel)
#     traceback.print_exc()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 331, in _bootstrap
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 163, in print_exc
#     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#     traceback.print_exc()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 105, in print_exception
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 163, in print_exc
#     traceback.print_exc()
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 163, in print_exc
#     print(line, file=file, end="")
# KeyboardInterrupt
#     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 105, in print_exception
#     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#   File "/Users/tommylee/opt/anaconda3/lib/python3.9/traceback.py", line 105, in print_exception
#     print(line, file=file, end="")
# KeyboardInterrupt
#     print(line, file=file, end="")
# KeyboardInterrupt

# %% [markdown]
# **(b)** PCA변환을 $X$에 적용하라. 이를 $\dot{X}$라 표기한다.
